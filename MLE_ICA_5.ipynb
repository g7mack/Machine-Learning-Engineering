# %% [markdown]
# <a href="https://colab.research.google.com/github/g7mack/Machine-Learning-Engineering/blob/main/MLE_ICA_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('SN Curve Plot Data.csv')

plt.scatter(df['x'], df[' y'])

plt.xscale('log')

plt.xlabel('Cycles to Failure, N')
plt.ylabel('Stress, ksi')
plt.title('SN Curve Plot Data')

plt.show()
